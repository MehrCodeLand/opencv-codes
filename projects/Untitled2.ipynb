# %%
import cv2 as cv
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
image = cv.imread('../images/book.png')

image_gray = cv.cvtColor(image , cv.COLOR_RGB2GRAY)

# %%
_ , binary_image =cv.threshold(image_gray , 200 , 255 , cv.THRESH_BINARY_INV)

# %%
plt.imshow(binary_image)
